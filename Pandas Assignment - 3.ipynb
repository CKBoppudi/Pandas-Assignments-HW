# %% [markdown]
# # Pandas Assignment - 3

# %% [markdown]
# # Assignment - 1

# %%
import numpy as np
import pandas as pd

# %%
data_1 = pd.read_csv(r"https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/716/original/sales_dataset.csv?1651727754")

# %%
data_1
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
data_1["Total"] = data_1["Quantity"] * data_1["Price"]

# %%
data_1
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country   Total
# ...

# %%
data_1["Total"].max()
# Out:
# 168469.6

# %%
data_1[data_1["Total"] == 168469.6]
# Out:
#         Invoice StockCode                  Description  Quantity  \
# 1065882  581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#                  InvoiceDate  Price  Customer ID         Country     Total
# 1065882  2011-12-09 09:15:00   2.08      16446.0  United Kingdom  168469.6

# %% [markdown]
# # Asisgnment - 2

# %%
data_2 = pd.read_csv(r"https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/715/original/sales_dataset.csv?1651726697")

# %%
data_2.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
mod = data_2.groupby('Description').sum()

# %%
mod
# Out:
#                                      Quantity   Price  Customer ID
# Description
#   DOORMAT UNION JACK GUNS AND ROSES       179  460.64     842345.0
#  3 STRIPEY MICE FELTCRAFT                 690  292.82    1791538.0
#  4 PURPLE FLOCK DINNER CANDLES            351  154.95     901806.0
#  50'S CHRISTMAS GIFT BAG LARGE           1913  185.28    1687133.0
#  ANIMAL STICKERS                          385    2.52     182720.0
# ...                                       ...     ...          ...
# wrongly marked carton 22804              -256    0.00          0.0
# wrongly marked. 23343 in box            -3100    0.00          0.0
# wrongly sold (22719) barcode              170    0.00          0.0
# wrongly sold as sets                     -600    0.00          0.0
# wrongly sold sets                        -975    0.00          0.0
#
# [5698 rows x 3 columns]

# %%
mod[mod['Quantity']==mod['Quantity'].max()]
# Out:
#                                    Quantity   Price  Customer ID
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS    108545  298.18   14628933.0

# %% [markdown]
# # Asssignment - 3

# %%
data_3 = pd.read_csv(r"https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/717/original/sales_dataset.csv?1651728217")

# %%
data_3
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
data_uk = data_3[data_3["Country"] == "United Kingdom"]

# %%
data_uk
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067350  581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 1067351  581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 1067352  581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 1067353  581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 1067354  581586     20685                DOORMAT RED RETROSPOT        10
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
data_uk["StockCode"].unique()
# Out:
# array(['85048', '79323P', '79323W', ..., '23609', '23617', '23843'],
#       dtype=object)

# %%
len(data_uk["StockCode"].unique())
# Out:
# 5303

# %% [markdown]
# # Note - Assignment Problems 4,5,6,7 solved on scaler dashboard as I have to code there.
